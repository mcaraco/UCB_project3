# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dropna.csv")
df = df.drop(df.columns[[0]], axis=1)
df
# Out:
#                    Country  QII_2012  QII_2013  QII_2014  QII_2015  QII_2016  \
# 0              Switzerland    194.11    215.71    206.23    222.94    208.54
# 1                  Germany    184.42    204.84    192.69    195.94    199.70
# 2                   Norway    183.43    173.86    168.41    175.09    188.90
# 3     United Arab Emirates    177.07    186.01    173.27    153.68    144.09
# 4              New Zealand    174.28    163.17    168.56    175.51    201.06
# 5                   Sweden    171.72    191.36    180.92    193.86    185.81
# 6                   Canada    164.99    186.03    178.29    177.63    177.23
# 7                  Denmark    163.12    182.29    178.55    190.18    206.49
# 8                Australia    162.03    165.80    175.98    180.81    198.79
# 9                  Austria    159.89    167.39    171.82    182.62    192.40
# 10             Netherlands    158.07    160.54    160.98    166.76    192.40
# ...

# %%
ff=df.loc[df["Country"]=="Germany"]
ff
# Out:
#    Country  QII_2012  QII_2013  QII_2014  QII_2015  QII_2016  QII_2017  \
# 1  Germany    184.42    204.84    192.69    195.94     199.7    189.74
#
#    QII_2019  QII_2018 ISO_A3  ...  GDP_2014  GDP_2015  GDP_2016  GDP_2017  \
# 1    187.05    190.04    DEU  ...  48218.87  41415.17  42460.69  44770.58
#
#    COMB_2012  COMB_2013  COMB_2014  COMB_2015  COMB_2016  COMB_2017
# 1      0.438      0.516      0.517      0.441      0.505      0.607
#
# [1 rows x 22 columns]

# %%
ff.to_dict("record")
# Out:
# [{'Country': 'Germany',
#   'QII_2012': 184.42,
#   'QII_2013': 204.84,
#   'QII_2014': 192.69,
#   'QII_2015': 195.94,
#   'QII_2016': 199.7,
#   'QII_2017': 189.74,
#   'QII_2019': 187.05,
#   'QII_2018': 190.04,
#   'ISO_A3': 'DEU',
#   'GDP_2012': 44089.28,
#   'GDP_2013': 46544.95,
#   'GDP_2014': 48218.87,
#   'GDP_2015': 41415.17,
#   'GDP_2016': 42460.69,
#   'GDP_2017': 44770.58,
#   'COMB_2012': 0.43799999999999994,
#   'COMB_2013': 0.516,
#   'COMB_2014': 0.517,
#   'COMB_2015': 0.441,
#   'COMB_2016': 0.505,
#   'COMB_2017': 0.607}]
